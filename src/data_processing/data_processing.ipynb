# %%
import pandas as pd

try:
    price_location = pd.read_csv('/workspaces/Coworking/src/results/LocationPLaces.csv')
    print('File correct exported!')
except Exception as e:
    print('Fallo inesperado')
    
price_location
# Out:
# File correct exported!
#                                                name   Neightboorhood  \
# 0                             Basis Point Shinbashi        Shinbashi
# 1                    Pasela Co-work Higashishinjuku  Higashishinjuku
# 2                            AWS Startup Loft Tokyo          Akasaka
# 3           LULL TECH BEACH shibuya coworking space          Shibuya
# 4                【法人登記可】コワーキングスペースfactoria nishiogi         Nishiogi
# 5                                         WORKVILLE          Midtown
# 6                                     Rise New York          Midtown
# 7                                 The Farm SoHo NYC             SoHo
# 8                                OASIS by Workville          Midtown
# 9                              The New Work Project     Williansburg
# 10                            Talent Garden Madrid          Delicias
# 11                                  Freeland Cowork          Adelfas
# 12                                     LOOM Huertas           Cortes
# 13                                          EslabOn           Opañel
# 14                                             Area         Delicias
# 15                   Betahaus | Coworking Barcelona           Gràcia
# 16  OneCoWork Plaça Catalunya | Barcelona Coworking     Ciutat Vella
# 17         OneCoWork Catedral | Barcelona Coworking     Ciutat Vella
# 18                          Coworking space Camaleó     Ciutat Vella
# 19                      La Vaca Coworking Barcelona   Sants-Montjuic
#
#     Population Median Household Income  \
# 0       100000               67,176.52
# 1        25000               46,506.82
# 2        50000               72,343.94
# 3       230000               56,841.67
# 4        80000               43,406.37
# 5        58789                  192347
# 6        58789                  192347
# 7        11675                  175209
# 8        58789                  192347
# 9       138980                   97432
# 10       28575               65,785.51
# 11       18832               73,676.81
# 12       10816               57,982.61
# 13       33883               44,714.49
# 14       28575               65,785.51
# 15      123973               34,591.30
# 16       45671               18,133.33
# 17       45671               18,133.33
# 18       45671               18,133.33
# 19       40157               27,115.94
#
#     Percentage of population between 16 and 64 years  Transport  Day Pass  \
# 0                                               0.65          4     25.84
# 1                                               0.65          3     20.67
# 2                                               0.65          3     31.00
# 3                                               0.65          3     31.00
# 4                                               0.65          3     20.67
# 5                                               0.70          6     49.00
# 6                                               0.70          6      0.00
# 7                                               0.70          4     29.00
# 8                                               0.70          6     49.00
# 9                                               0.60          2     40.00
# 10                                              0.70          6     28.99
# 11                                              0.65          5     28.99
# 12                                              0.76         10     43.48
# 13                                              0.70          4     21.74
# 14                                              0.70          4     28.99
# 15                                              0.66          1     28.99
# 16                                              0.75          5     36.23
# 17                                              0.75          5     36.23
# 18                                              0.75          3     36.23
# 19                                              0.63          2     31.88
#
#     Month Pass
# 0       413.39
# 1       310.05
# 2       465.07
# 3       413.39
# 4       310.05
# 5       300.00
# 6       250.00
# 7       179.00
# 8       350.00
# 9       370.00
# 10      413.04
# 11      217.39
# 12      398.55
# 13      259.42
# 14      347.83
# 15      398.55
# 16      340.58
# 17      384.06
# 18      289.86
# 19      347.83

# %%
price_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   name                                              20 non-null     object
#  1   Neightboorhood                                    20 non-null     object
#  2   Population                                        20 non-null     int64
#  3   Median Household Income                           20 non-null     object
#  4   Percentage of population between 16 and 64 years  20 non-null     float64
#  5   Transport                                         20 non-null     int64
#  6   Day Pass                                          20 non-null     float64
#  7   Month Pass                                        20 non-null     float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 1.4+ KB

# %%
price_location.
