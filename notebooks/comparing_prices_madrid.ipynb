# %% [markdown]
# ## Comparing Prices

# %%
import csv

# Specify the file path
file_path = 'PreciosCoworking.csv'

# Open the file in read mode
with open(file_path, 'r') as csv_file:
    # Create a CSV reader object
    csv_reader = csv.reader(csv_file)
    
    # Iterate over each row in the CSV file
    for row in csv_reader:
        # Do something with the row
        print(row)
# Out:
# ['', 'EslabOn', 'Area', 'Freeland', 'Talent Garden', 'Loom']
# ['Mesa Fija', '179', '240', '150', '285', '275']
# ['Mesa Flexible', '139', '180', '95', '195', '125']
# ['Despacho Priado', '300', '1000', '375', '400', '']
# ['Pases/Bonos (días)', '15', '20', '20', '20', '30']

# %%
import pandas as pd

prices_coworking = pd.read_csv(file_path)

print(prices_coworking)
# Out:
#            Unnamed: 0  EslabOn  Area  Freeland  Talent Garden   Loom
# 0           Mesa Fija      179   240       150            285  275.0
# 1       Mesa Flexible      139   180        95            195  125.0
# 2     Despacho Priado      300  1000       375            400    NaN
# 3  Pases/Bonos (días)       15    20        20             20   30.0

# %%
numeric_df = prices_coworking.iloc[:, 1:]

prices_coworking['Mean'] = numeric_df.mean(axis=1)

numeric_df = prices_coworking.iloc[:, 1:]

prices_coworking['Std. Deviation'] = numeric_df.std(axis=1)

prices_coworking
# Out:
#            Unnamed: 0  EslabOn  Area  Freeland  Talent Garden   Loom    Mean  \
# 0           Mesa Fija      179   240       150            285  275.0  225.80
# 1       Mesa Flexible      139   180        95            195  125.0  146.80
# 2     Despacho Priado      300  1000       375            400    NaN  518.75
# 3  Pases/Bonos (días)       15    20        20             20   30.0   21.00
#
#    Std. Deviation
# 0       53.033574
# 1       36.454904
# 2      280.276092
# 3        4.898979

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Selecting the first row excluding the first column
data = prices_coworking.iloc[0, 1:6]

# Plotting a bar plot for the first row
ax = data.plot(kind='bar', figsize=(10, 6), color='blue', label='Price')

# Adding a line plot for the mean
mean_line = prices_coworking.iloc[0]['Mean']
ax.axhline(y=mean_line, color='red', linestyle='--', label='Mean')

for i, v in enumerate(data):
    ax.text(i, v + 10, str(v), ha='center', va='bottom')

# Annotating mean line with its value
ax.text(0, mean_line + 10, f'Mean: {mean_line}', color='red', ha='center', va='bottom')

plt.title('Comparing fixed desk prices')
plt.xlabel('Coworking')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Selecting the first row excluding the first column
data = prices_coworking.iloc[1, 1:6]

# Plotting a bar plot for the first row
ax = data.plot(kind='bar', figsize=(10, 6), color='blue', label='Price')

# Adding a line plot for the mean
mean_line = prices_coworking.iloc[1]['Mean']
ax.axhline(y=mean_line, color='red', linestyle='--', label='Mean')

for i, v in enumerate(data):
    ax.text(i, v + 10, str(v), ha='center', va='bottom')

# Annotating mean line with its value
ax.text(0, mean_line + 10, f'Mean: {mean_line}', color='red', ha='center', va='bottom')

plt.title('Comparing flexible desk prices')
plt.xlabel('Coworking')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Selecting the first row excluding the first column
data = prices_coworking.iloc[2, 1:6]

# Plotting a bar plot for the first row
ax = data.plot(kind='bar', figsize=(10, 6), color='blue', label='Price')

# Adding a line plot for the mean
mean_line = prices_coworking.iloc[2]['Mean']
ax.axhline(y=mean_line, color='red', linestyle='--', label='Mean')

for i, v in enumerate(data):
    ax.text(i, v + 10, str(v), ha='center', va='bottom')

# Annotating mean line with its value
ax.text(0, mean_line + 10, f'Mean: {mean_line}', color='red', ha='center', va='bottom')

plt.title('Comparing private cabin desk prices')
plt.xlabel('Coworking')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Selecting the first row excluding the first column
data = prices_coworking.iloc[3, 1:6]

# Plotting a bar plot for the first row
ax = data.plot(kind='bar', figsize=(10, 6), color='blue', label='Price')

# Adding a line plot for the mean
mean_line = prices_coworking.iloc[3]['Mean']
ax.axhline(y=mean_line, color='red', linestyle='--', label='Mean')

for i, v in enumerate(data):
    ax.text(i, v + 10, str(v), ha='center', va='bottom')

# Annotating mean line with its value
ax.text(0, mean_line + 10, f'Mean: {mean_line}', color='red', ha='center', va='bottom')

plt.title('Comparing daily pass desk prices')
plt.xlabel('Coworking')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend()
plt.tight_layout()
plt.show()
